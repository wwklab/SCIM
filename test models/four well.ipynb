# %%
import argparse
import random

import scipy.sparse as sp
import scipy.sparse.csgraph
import sklearn.linear_model as sklm
import sklearn.metrics as skm
import sklearn.model_selection as skms
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from ignite.engine import Engine, Events
from ignite.handlers import ModelCheckpoint
from torch.utils.data import DataLoader, IterableDataset, get_worker_info

CHECKPOINT_PREFIX = "g2g"

from utils import *
# from minepy import MINE
from sklearn.preprocessing import MinMaxScaler

# %%
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.current_device())
# Out:
# 2.1.2
# 11.8
# True
# 1
# 0

# %%
method = ''
from g2g_model_Fisher import *

# %%
model_name = 'four well'
result_path = 'results/'+model_name+'/'
figure_path = 'figures/'
cmap = plt.colormaps['Spectral_r']

# %%
import os

folder = os.path.exists(result_path)
if not folder:                   #判断是否存在文件夹如果不存在则创建为文件夹
    os.makedirs(result_path)

# %%
# Define the double well potential function
def four_well_potential(x, y):
    # return 0.05*x**4-x**2+0.05*y**4-(y-0.5)**2
    return 0.05*x**4-x**2+0.05*y**4-y**2

# Define the range of x and y values to plot


x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)

# Create a 2D grid of x and y values
X, Y = np.meshgrid(x, y)

# Calculate the potential energy at each point in the grid
Z = four_well_potential(X, Y)

# %%
# Create a 3D surface plot of the potential energy
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0, antialiased=False)
ax.grid(False)
# ax.view_init(0, 90)
# ax.set_xlabel('X')
# ax.set_ylabel('Y')
# ax.set_zlabel('Z')
ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])
plt.axis('off')
# plt.axis('equal')

# plt.savefig(result_path+model_name+'.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
X0 = np.load('results/X.npy')
V0 = np.load('results/V.npy')
U0 = np.load('results/U.npy')
n_samples = X0.shape[0]

# %%
from sklearn.decomposition import PCA

color_label = np.zeros((n_samples))
color_label[np.argsort(X0[:,0])] = np.arange(n_samples)
pca=PCA(n_components=3).fit(X0)
S_pca=pca.transform(X0)
plt.scatter(S_pca[:,0],S_pca[:,1],s=10,c=color_label,cmap=plt.cm.jet)
plt.show()
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection="3d")
fig.add_axes(ax)
ax.scatter(
    S_pca[:, 0],S_pca[:, 1], S_pca[:, 2], c=color_label, s=20, alpha=0.8,cmap=plt.cm.jet
)
plt.show()

# %%
X = X0[::2]
V = V0[::2]
U = U0[::2]

# %%
k_nei = 10
A = kneighbors_graph(X, k_nei, mode='connectivity', include_self=True)
# A=radius_neighbors_graph(X,3,include_self=True)
X_major = X[:,:3]

row =np.array([np.ones((k_nei,))*i for i in range(n_samples)]).flatten()
col=A.indices
w_val=np.array([np.linalg.norm(X_major[int(i),:]-X_major[int(j),:]) for i,j in zip(row,col)])
dc=np.mean(w_val)

cell_nei=A.indices.reshape(X.shape[0],10)
nei_w=[]
rho_arr=[]
for ni in cell_nei:
    dij=np.array([np.linalg.norm(X_major[int(ni[0]),:]-X_major[int(i),:]) for i in ni[1:]])
    rho=np.sum(np.exp(-dij**2/dc**2))
#     rho=np.exp(np.sum(-dij**2/dc**2))
    nei_w.append(np.exp(-dij**2/dc**2)/np.sum(np.exp(-dij**2/dc**2)))
#     print(dij)
#     print(np.exp(-dij**2/dc**2)/np.sum(np.exp(-dij**2/dc**2)))
    rho_arr.append(rho)
rho_arr=np.array(rho_arr)/np.amax(rho_arr)
nei_w=np.array(nei_w)
nei_w=np.hstack((np.ones((nei_w.shape[0],1)),nei_w))/2

# plt.scatter(X_pca[:,0],X_pca[:,1],s=5,c=rho_arr,cmap=plt.cm.jet)
# plt.colorbar()
# plt.show()

def smooth_func(X_val,cell_nei=cell_nei,nei_w=nei_w):
    X_s=X_val.copy()
    for ci in range(len(X_val)):
        X_s[ci]=np.dot(X_val[cell_nei[ci,:]],nei_w[ci,:])
    return X_s
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_26276\3184053074.py:18: RuntimeWarning: invalid value encountered in divide
#   nei_w.append(np.exp(-dij**2/dc**2)/np.sum(np.exp(-dij**2/dc**2)))

# %%
epochs = 200
nsamples = 3
learning_rate = 1e-3
# n_workers = 4
K = 2
L = 3
#     checkpoint_path = args.checkpoint
#     checkpoints_path = args.checkpoints
#     dataset_path = args.dataset

# %%
# for i in range(10):
#     reset_seeds(i)
#     A=A.astype(np.float32)
#     X=X.astype(np.float32)
#     z=color_label

#     n = A.shape[0]
#     train_nodes, val_nodes = train_test_split(n, train_ratio=1)
#     A_train = A[train_nodes, :][:, train_nodes]
#     X_train = X[train_nodes]
#     z_train = z[train_nodes]
#     A_val = A[val_nodes, :][:, val_nodes]
#     X_val = X[val_nodes]
#     z_val = z[val_nodes]

#     train_data = AttributedGraph(A_train, X_train, z_train, K)
#     val_data = AttributedGraph(A_val, X_val, z_val, K)
    
#     encoder = Encoder(X.shape[1], L)
#     optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
#     iterations = epochs #// n_workers
#     dataset = GraphDataset(train_data, nsamples, iterations)
#     loader = DataLoader(
#         dataset,
#         batch_size=1,
#         #num_workers=n_workers,
#         worker_init_fn=reset_seeds,
#         collate_fn=lambda args: args,
#     )
    
#     for batch_idx, data in enumerate(loader):
#         encoder.train()
#         optimizer.zero_grad()

#         loss = encoder.compute_loss(data[0][0],data[0][1],data[0][2],data[0][3],data[0][4],data[0][5])
#         if batch_idx% 10 == 0:
#             print(batch_idx,loss)
#         loss.backward()
#         optimizer.step()
        
#     torch.save(encoder,result_path+'encoder'+str(i)+'.pt')
    
#     mu, sigma = encoder(torch.FloatTensor(X))
#     X_mu = mu.detach().numpy()
#     X_sigma = sigma.detach().numpy()#The learned sigma is variance

# #     cRc_arr=[]
#     cRc_arr_eu=[]
# #     cRc_arr_mueu=[]
#     mu_learned = X_mu
#     sigma_learned = X_sigma

#     for inds in np.split(A.indices, A.indptr)[1:-1]:
#         self_ind=inds[0]
# #         cRc=0
#         cRc_eu=0
# #         cRc_mueu=0
#         for nei_k in range(1,len(inds)):
#             dEu=np.linalg.norm(X[self_ind,:]-X[inds[nei_k],:])
# #             dMuEu=np.linalg.norm(X_mu[self_ind,:]-X_mu[inds[nei_k],:])
# #             dFi=Fisher_dist(mu_learned[self_ind,:],sigma_learned[self_ind,:],\
# #                             mu_learned[inds[nei_k],:],sigma_learned[inds[nei_k],:])
#             dWa=wasserstein_distance(mu_learned[self_ind,:],sigma_learned[self_ind,:],\
#                             mu_learned[inds[nei_k],:],sigma_learned[inds[nei_k],:])

# #             cRc += 1-dWa/dFi
#             cRc_eu += 1-dWa/dEu
# #             cRc_mueu += 1-dWa/dMuEu

# #         cRc_arr.append(cRc/len(inds))
#         cRc_arr_eu.append(cRc_eu/len(inds))
# #         cRc_arr_mueu.append(cRc_mueu/len(inds))
# #     orc = np.array(cRc_arr)
#     orc_eu = np.array(cRc_arr_eu)
# #     orc_mueu = np.array(cRc_arr_mueu)
    
#     np.save(result_path+'crc'+str(i),orc_eu)
# Out:
# 0 tensor(1.1321e+08, grad_fn=<DivBackward0>)
# 10 tensor(39661164., grad_fn=<DivBackward0>)
# 20 tensor(37593004., grad_fn=<DivBackward0>)
# 30 tensor(36473156., grad_fn=<DivBackward0>)
# 40 tensor(35642932., grad_fn=<DivBackward0>)
# 50 tensor(36111368., grad_fn=<DivBackward0>)
# 60 tensor(35078660., grad_fn=<DivBackward0>)
# 70 tensor(34175228., grad_fn=<DivBackward0>)
# 80 tensor(34411236., grad_fn=<DivBackward0>)
# 90 tensor(33499104., grad_fn=<DivBackward0>)
# 100 tensor(33905312., grad_fn=<DivBackward0>)
# 110 tensor(33249728., grad_fn=<DivBackward0>)
# 120 tensor(33147376., grad_fn=<DivBackward0>)
# 130 tensor(32439094., grad_fn=<DivBackward0>)
# 140 tensor(32515302., grad_fn=<DivBackward0>)
# 150 tensor(33158888., grad_fn=<DivBackward0>)
# 160 tensor(33522278., grad_fn=<DivBackward0>)
# 170 tensor(32122192., grad_fn=<DivBackward0>)
# 180 tensor(32114784., grad_fn=<DivBackward0>)
# 190 tensor(32461104., grad_fn=<DivBackward0>)
# 0 tensor(76652296., grad_fn=<DivBackward0>)
# 10 tensor(42757528., grad_fn=<DivBackward0>)
# 20 tensor(38533932., grad_fn=<DivBackward0>)
# 30 tensor(36174636., grad_fn=<DivBackward0>)
# 40 tensor(35216452., grad_fn=<DivBackward0>)
# 50 tensor(34492772., grad_fn=<DivBackward0>)
# 60 tensor(34293132., grad_fn=<DivBackward0>)
# 70 tensor(33648924., grad_fn=<DivBackward0>)
# 80 tensor(33825456., grad_fn=<DivBackward0>)
# 90 tensor(32881978., grad_fn=<DivBackward0>)
# 100 tensor(32941968., grad_fn=<DivBackward0>)
# 110 tensor(32945846., grad_fn=<DivBackward0>)
# 120 tensor(33398834., grad_fn=<DivBackward0>)
# 130 tensor(32446550., grad_fn=<DivBackward0>)
# 140 tensor(32945078., grad_fn=<DivBackward0>)
# 150 tensor(32246304., grad_fn=<DivBackward0>)
# 160 tensor(32743318., grad_fn=<DivBackward0>)
# 170 tensor(31642086., grad_fn=<DivBackward0>)
# 180 tensor(32462928., grad_fn=<DivBackward0>)
# 190 tensor(32311098., grad_fn=<DivBackward0>)
# 0 tensor(54773776., grad_fn=<DivBackward0>)
# 10 tensor(38003408., grad_fn=<DivBackward0>)
# 20 tensor(36122976., grad_fn=<DivBackward0>)
# 30 tensor(34850236., grad_fn=<DivBackward0>)
# 40 tensor(33442550., grad_fn=<DivBackward0>)
# 50 tensor(33508080., grad_fn=<DivBackward0>)
# 60 tensor(33091862., grad_fn=<DivBackward0>)
# 70 tensor(32715566., grad_fn=<DivBackward0>)
# 80 tensor(32901554., grad_fn=<DivBackward0>)
# 90 tensor(32739862., grad_fn=<DivBackward0>)
# 100 tensor(32506390., grad_fn=<DivBackward0>)
# 110 tensor(32749494., grad_fn=<DivBackward0>)
# 120 tensor(32441056., grad_fn=<DivBackward0>)
# 130 tensor(32071952., grad_fn=<DivBackward0>)
# 140 tensor(31950928., grad_fn=<DivBackward0>)
# 150 tensor(32252634., grad_fn=<DivBackward0>)
# 160 tensor(32215952., grad_fn=<DivBackward0>)
# 170 tensor(32243808., grad_fn=<DivBackward0>)
# 180 tensor(31717738., grad_fn=<DivBackward0>)
# 190 tensor(31703960., grad_fn=<DivBackward0>)
# 0 tensor(1.0450e+08, grad_fn=<DivBackward0>)
# 10 tensor(43450588., grad_fn=<DivBackward0>)
# 20 tensor(38814212., grad_fn=<DivBackward0>)
# 30 tensor(36780724., grad_fn=<DivBackward0>)
# 40 tensor(35808084., grad_fn=<DivBackward0>)
# 50 tensor(34937452., grad_fn=<DivBackward0>)
# 60 tensor(34118188., grad_fn=<DivBackward0>)
# 70 tensor(34078724., grad_fn=<DivBackward0>)
# 80 tensor(33934444., grad_fn=<DivBackward0>)
# 90 tensor(32789358., grad_fn=<DivBackward0>)
# 100 tensor(32680738., grad_fn=<DivBackward0>)
# 110 tensor(33074792., grad_fn=<DivBackward0>)
# 120 tensor(33026272., grad_fn=<DivBackward0>)
# 130 tensor(32594666., grad_fn=<DivBackward0>)
# 140 tensor(33074882., grad_fn=<DivBackward0>)
# 150 tensor(32501126., grad_fn=<DivBackward0>)
# 160 tensor(32385216., grad_fn=<DivBackward0>)
# 170 tensor(32416758., grad_fn=<DivBackward0>)
# 180 tensor(32367878., grad_fn=<DivBackward0>)
# 190 tensor(32517898., grad_fn=<DivBackward0>)
# 0 tensor(82455912., grad_fn=<DivBackward0>)
# 10 tensor(41183532., grad_fn=<DivBackward0>)
# 20 tensor(37068548., grad_fn=<DivBackward0>)
# 30 tensor(34966828., grad_fn=<DivBackward0>)
# 40 tensor(34663428., grad_fn=<DivBackward0>)
# 50 tensor(33952812., grad_fn=<DivBackward0>)
# 60 tensor(33736516., grad_fn=<DivBackward0>)
# 70 tensor(32862226., grad_fn=<DivBackward0>)
# 80 tensor(32782282., grad_fn=<DivBackward0>)
# 90 tensor(33056048., grad_fn=<DivBackward0>)
# 100 tensor(32713170., grad_fn=<DivBackward0>)
# 110 tensor(32392864., grad_fn=<DivBackward0>)
# 120 tensor(32390142., grad_fn=<DivBackward0>)
# 130 tensor(31841424., grad_fn=<DivBackward0>)
# 140 tensor(32590570., grad_fn=<DivBackward0>)
# 150 tensor(31990530., grad_fn=<DivBackward0>)
# 160 tensor(32241856., grad_fn=<DivBackward0>)
# 170 tensor(32263480., grad_fn=<DivBackward0>)
# 180 tensor(31878056., grad_fn=<DivBackward0>)
# 190 tensor(31425856., grad_fn=<DivBackward0>)
# 0 tensor(89238584., grad_fn=<DivBackward0>)
# 10 tensor(41381872., grad_fn=<DivBackward0>)
# 20 tensor(37522688., grad_fn=<DivBackward0>)
# 30 tensor(36035840., grad_fn=<DivBackward0>)
# 40 tensor(35185448., grad_fn=<DivBackward0>)
# 50 tensor(35469256., grad_fn=<DivBackward0>)
# 60 tensor(34330152., grad_fn=<DivBackward0>)
# 70 tensor(34096388., grad_fn=<DivBackward0>)
# 80 tensor(33749472., grad_fn=<DivBackward0>)
# 90 tensor(33636920., grad_fn=<DivBackward0>)
# 100 tensor(32804104., grad_fn=<DivBackward0>)
# 110 tensor(33085104., grad_fn=<DivBackward0>)
# 120 tensor(32892722., grad_fn=<DivBackward0>)
# 130 tensor(32712826., grad_fn=<DivBackward0>)
# 140 tensor(32598688., grad_fn=<DivBackward0>)
# 150 tensor(32423610., grad_fn=<DivBackward0>)
# 160 tensor(32540400., grad_fn=<DivBackward0>)
# 170 tensor(32515808., grad_fn=<DivBackward0>)
# 180 tensor(32066506., grad_fn=<DivBackward0>)
# 190 tensor(32638512., grad_fn=<DivBackward0>)
# 0 tensor(67360136., grad_fn=<DivBackward0>)
# 10 tensor(38275484., grad_fn=<DivBackward0>)
# 20 tensor(36029504., grad_fn=<DivBackward0>)
# 30 tensor(34514756., grad_fn=<DivBackward0>)
# 40 tensor(33957404., grad_fn=<DivBackward0>)
# 50 tensor(33413064., grad_fn=<DivBackward0>)
# 60 tensor(33982364., grad_fn=<DivBackward0>)
# 70 tensor(33264022., grad_fn=<DivBackward0>)
# 80 tensor(33314902., grad_fn=<DivBackward0>)
# 90 tensor(32286550., grad_fn=<DivBackward0>)
# 100 tensor(32689878., grad_fn=<DivBackward0>)
# 110 tensor(33007042., grad_fn=<DivBackward0>)
# 120 tensor(32304054., grad_fn=<DivBackward0>)
# 130 tensor(32296616., grad_fn=<DivBackward0>)
# 140 tensor(32457138., grad_fn=<DivBackward0>)
# 150 tensor(32225634., grad_fn=<DivBackward0>)
# 160 tensor(32378618., grad_fn=<DivBackward0>)
# 170 tensor(32437382., grad_fn=<DivBackward0>)
# 180 tensor(31629302., grad_fn=<DivBackward0>)
# 190 tensor(32111218., grad_fn=<DivBackward0>)
# 0 tensor(84337896., grad_fn=<DivBackward0>)
# 10 tensor(40013268., grad_fn=<DivBackward0>)
# 20 tensor(36795676., grad_fn=<DivBackward0>)
# 30 tensor(35602272., grad_fn=<DivBackward0>)
# 40 tensor(34466452., grad_fn=<DivBackward0>)
# 50 tensor(34093116., grad_fn=<DivBackward0>)
# 60 tensor(33561036., grad_fn=<DivBackward0>)
# 70 tensor(32928168., grad_fn=<DivBackward0>)
# 80 tensor(33120410., grad_fn=<DivBackward0>)
# 90 tensor(32417446., grad_fn=<DivBackward0>)
# 100 tensor(33274440., grad_fn=<DivBackward0>)
# 110 tensor(32271152., grad_fn=<DivBackward0>)
# 120 tensor(32302878., grad_fn=<DivBackward0>)
# 130 tensor(32492394., grad_fn=<DivBackward0>)
# 140 tensor(32756806., grad_fn=<DivBackward0>)
# 150 tensor(32721526., grad_fn=<DivBackward0>)
# 160 tensor(31433178., grad_fn=<DivBackward0>)
# 170 tensor(32164856., grad_fn=<DivBackward0>)
# 180 tensor(31766056., grad_fn=<DivBackward0>)
# 190 tensor(32393144., grad_fn=<DivBackward0>)
# 0 tensor(68567048., grad_fn=<DivBackward0>)
# 10 tensor(39266220., grad_fn=<DivBackward0>)
# 20 tensor(36781364., grad_fn=<DivBackward0>)
# 30 tensor(34884360., grad_fn=<DivBackward0>)
# 40 tensor(33880108., grad_fn=<DivBackward0>)
# 50 tensor(33932700., grad_fn=<DivBackward0>)
# 60 tensor(33424032., grad_fn=<DivBackward0>)
# 70 tensor(33370144., grad_fn=<DivBackward0>)
# 80 tensor(33197608., grad_fn=<DivBackward0>)
# 90 tensor(32573562., grad_fn=<DivBackward0>)
# 100 tensor(32385576., grad_fn=<DivBackward0>)
# 110 tensor(32458938., grad_fn=<DivBackward0>)
# 120 tensor(32664414., grad_fn=<DivBackward0>)
# 130 tensor(31914810., grad_fn=<DivBackward0>)
# 140 tensor(33057094., grad_fn=<DivBackward0>)
# 150 tensor(32030774., grad_fn=<DivBackward0>)
# 160 tensor(32132118., grad_fn=<DivBackward0>)
# 170 tensor(31557786., grad_fn=<DivBackward0>)
# 180 tensor(32065062., grad_fn=<DivBackward0>)
# 190 tensor(31620602., grad_fn=<DivBackward0>)
# 0 tensor(59969152., grad_fn=<DivBackward0>)
# 10 tensor(38422368., grad_fn=<DivBackward0>)
# 20 tensor(35810604., grad_fn=<DivBackward0>)
# 30 tensor(34928940., grad_fn=<DivBackward0>)
# 40 tensor(34227716., grad_fn=<DivBackward0>)
# 50 tensor(33661028., grad_fn=<DivBackward0>)
# 60 tensor(33731784., grad_fn=<DivBackward0>)
# 70 tensor(33156846., grad_fn=<DivBackward0>)
# 80 tensor(33101402., grad_fn=<DivBackward0>)
# 90 tensor(33239978., grad_fn=<DivBackward0>)
# 100 tensor(32367526., grad_fn=<DivBackward0>)
# 110 tensor(32303152., grad_fn=<DivBackward0>)
# 120 tensor(32604630., grad_fn=<DivBackward0>)
# 130 tensor(32586858., grad_fn=<DivBackward0>)
# 140 tensor(31922970., grad_fn=<DivBackward0>)
# 150 tensor(32014304., grad_fn=<DivBackward0>)
# 160 tensor(32244048., grad_fn=<DivBackward0>)
# 170 tensor(32101794., grad_fn=<DivBackward0>)
# 180 tensor(32150982., grad_fn=<DivBackward0>)
# 190 tensor(31734618., grad_fn=<DivBackward0>)

# %%
encoders = [0]*10
mus = [0]*10
sgms = [0]*10
crcs_smooth = [0]*10
for i in range(10):
    encoders[i] = torch.load(result_path+'encoder'+str(i)+'.pt')
    mu, sigma = encoders[i](torch.FloatTensor(X))
    mus[i] = mu.detach().numpy()
    sgms[i] = sigma.detach().numpy()
    crcs_smooth[i] = smooth_func(np.load(result_path+'crc'+str(i)+'.npy'))
encoders = np.array(encoders)
mus = np.array(mus)
sgms = np.array(sgms)
crcs_smooth = np.array(crcs_smooth)

# %%
for n10 in range(10):
    X_plt = sgms[n10,:,0]
    Y_plt = sgms[n10,:,1]
    X_min = np.min(X_plt)
    X_max = np.max(X_plt)
    Y_min = np.min(Y_plt)
    Y_max = np.max(Y_plt)
    X_len = (X_max-X_min)/5
    Y_len = (Y_max-Y_min)/5
    wid = min(X_len,Y_len)/30
    X_ori = X_min+5*wid
    Y_ori = Y_min+5*wid
    
    plt.scatter(X_plt,Y_plt,s=30,alpha=0.8,c=X[:,2],cmap='viridis')
    plt.axis('off')
    
    plt.arrow(X_ori-wid/2,Y_ori,X_len,0,width=wid*1.5,color='black',head_width=12*wid,head_length=5*wid)
    plt.arrow(X_ori,Y_ori-wid/2,0,Y_len,width=wid*2/3,color='black',head_width=4*wid,head_length=14*wid)
    
    plt.text(X_ori+X_len/2,Y_ori-wid*22,'$\mu_1$',fontsize=20,ha='center',weight='bold')
    plt.text(X_ori-wid*7,Y_ori+Y_len/2,'$\mu_2$',fontsize=20,ha='center',weight='bold')
    
    # plt.savefig(result_path+model_name+'_mu.png',dpi=600,bbox_inches='tight')
    plt.show()

# %%
n10 = 3
X_plt = -sgms[n10,:,0]
Y_plt = sgms[n10,:,1]
X_min = np.min(X_plt)
X_max = np.max(X_plt)
Y_min = np.min(Y_plt)
Y_max = np.max(Y_plt)
X_len = (X_max-X_min)/5
Y_len = (Y_max-Y_min)/5
wid = min(X_len,Y_len)/30
X_ori = X_min+5*wid
Y_ori = Y_min+5*wid

plt.scatter(X_plt,Y_plt,s=30,alpha=0.8,c=X[:,2],cmap='viridis')
plt.axis('off')

plt.arrow(X_ori-wid/2,Y_ori,X_len,0,width=wid,color='black',head_width=5*wid,head_length=7*wid)
plt.arrow(X_ori,Y_ori-wid/2,0,Y_len,width=wid,color='black',head_width=4*wid,head_length=8*wid)

plt.text(X_ori+X_len/2,Y_ori-wid*10,'$\sigma_1$',fontsize=20,ha='center',weight='bold')
plt.text(X_ori-wid*8,Y_ori+Y_len/2,'$\sigma_2$',fontsize=20,ha='center',weight='bold')

plt.savefig(figure_path+'2b3.png',dpi=600,bbox_inches='tight')
plt.show()

# %%
plt.scatter(
    X[:, 0], X[:, 1], c=crcs_smooth[6,:], s=30, alpha=0.8,cmap=cmap
    # X[:, 0], X[:, 1], c=np.mean(crcs_smooth,axis=0), s=30, alpha=0.8,cmap=cmap
)
plt.show()
